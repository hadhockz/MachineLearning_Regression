# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the dataset
dts = pd.read_csv("insurance_pre.csv")

# %%
dts
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dts = pd.get_dummies(dts,drop_first=True)

# %%
dts
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#columns rename-ing
dts.rename(columns={"sex_male":"sex","smoker_yes":"smoker","charges":"premium_amt"},inplace=True)

# %%
dts
# Out:
#       age     bmi  children  premium_amt  sex  smoker
# 0      19  27.900         0  16884.92400    0       1
# 1      18  33.770         1   1725.55230    1       0
# 2      28  33.000         3   4449.46200    1       0
# 3      33  22.705         0  21984.47061    1       0
# 4      32  28.880         0   3866.85520    1       0
# ...   ...     ...       ...          ...  ...     ...
# 1333   50  30.970         3  10600.54830    1       0
# 1334   18  31.920         0   2205.98080    0       0
# 1335   18  36.850         0   1629.83350    0       0
# 1336   21  25.800         0   2007.94500    0       0
# 1337   61  29.070         0  29141.36030    0       1
#
# [1338 rows x 6 columns]

# %%
dts.columns
# Out:
# Index(['age', 'bmi', 'children', 'premium_amt', 'sex', 'smoker'], dtype='object')

# %%
features = dts[["age","bmi","children","sex","smoker"]]
target = dts[["premium_amt"]]

# %%
features
# Out:
#       age     bmi  children  sex  smoker
# 0      19  27.900         0    0       1
# 1      18  33.770         1    1       0
# 2      28  33.000         3    1       0
# 3      33  22.705         0    1       0
# 4      32  28.880         0    1       0
# ...   ...     ...       ...  ...     ...
# 1333   50  30.970         3    1       0
# 1334   18  31.920         0    0       0
# 1335   18  36.850         0    0       0
# 1336   21  25.800         0    0       0
# 1337   61  29.070         0    0       1
#
# [1338 rows x 5 columns]

# %%
target
# Out:
#       premium_amt
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#import SVR & GRIDSEARCH Libraries
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
hyperparam_grid = {"kernel":["rbf","sigmoid","linear"],
                   "C" : [10,50,200,300],
                   "gamma" : ["auto","scale"]}

grid = GridSearchCV(SVR(), hyperparam_grid,cv = 3, 
                    refit = True, verbose = 3, n_jobs = -1)

#model fitting for grid search
grid.fit(features,target)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/had/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 50, 200, 300], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#printing best parameter after iterations from mentioned hyperparameters.

re = grid.cv_results_
print("The R2 score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R2 score value for best parameter {'C': 300, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
#Table building for data's
table = pd.DataFrame.from_dict(re)
#os library to perform file management process.
import os
#Directory to save the xlsx file
directory = '/home/had/jnotebook/HOPE_py_training/MachineLearning-Regression/GridSearchCV'
#file path for the xlsx file
file_path = os.path.join(directory,"iterations_SVR.xlsx")
#Save the dataframe to xlsx
table.to_excel(file_path,index=False)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.156464      0.019957         0.084344        0.019223      10
# 1        0.085880      0.000593         0.033573        0.001049      10
# 2        0.114862      0.004781         0.031817        0.000854      10
# 3        0.093857      0.001898         0.058158        0.000530      10
# 4        0.129746      0.000564         0.052271        0.001708      10
# 5        0.092008      0.002620         0.032717        0.001164      10
# 6        0.119491      0.003751         0.057801        0.001935      50
# 7        0.089362      0.006723         0.032200        0.000542      50
# 8        0.129939      0.009915         0.037630        0.007628      50
# 9        0.123837      0.020341         0.103724        0.006983      50
# 10       0.134734      0.009571         0.056748        0.002759      50
# 11       0.132111      0.005866         0.030325        0.000413      50
# 12       0.156527      0.022560         0.085260        0.013148     200
# 13       0.091928      0.011862         0.035445        0.000691     200
# 14       0.253544      0.017637         0.030353        0.001734     200
# 15       0.101366      0.008479         0.059178        0.001474     200
# 16       0.126589      0.004821         0.051107        0.000594     200
# 17       0.236264      0.014067         0.029486        0.000552     200
# 18       0.129849      0.004149         0.063773        0.004852     300
# 19       0.081821      0.002893         0.031989        0.000207     300
# 20       0.336134      0.033843         0.026517        0.004692     300
# 21       0.094619      0.008579         0.058420        0.001606     300
# 22       0.121154      0.001648         0.051445        0.000830     300
# 23       0.264564      0.051450         0.023596        0.005550     300
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.121859
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.029744
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.120647
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.126045
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.029744
# 6         {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}          -0.116373
# 7     {'C': 50, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 8      {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}           0.365731
# 9        {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143480
# 10   {'C': 50, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.138108
# 11    {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}           0.365731
# 12       {'C': 200, 'gamma': 'auto', 'kernel': 'rbf'}          -0.106332
# 13   {'C': 200, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 14    {'C': 200, 'gamma': 'auto', 'kernel': 'linear'}           0.580482
# 15      {'C': 200, 'gamma': 'scale', 'kernel': 'rbf'}          -0.152099
# 16  {'C': 200, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.200818
# 17   {'C': 200, 'gamma': 'scale', 'kernel': 'linear'}           0.580482
# 18       {'C': 300, 'gamma': 'auto', 'kernel': 'rbf'}          -0.097433
# 19   {'C': 300, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 20    {'C': 300, 'gamma': 'auto', 'kernel': 'linear'}           0.596022
# 21      {'C': 300, 'gamma': 'scale', 'kernel': 'rbf'}          -0.152276
# 22  {'C': 300, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.272206
# 23   {'C': 300, 'gamma': 'scale', 'kernel': 'linear'}           0.596022
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.071812          -0.115978        -0.103216        0.022336
# 1           -0.073333          -0.116351        -0.104664        0.022391
# 2            0.024305          -0.087219        -0.030886        0.045536
# 3           -0.062407          -0.126932        -0.103329        0.029050
# 4           -0.075274          -0.117573        -0.106297        0.022208
# 5            0.024305          -0.087219        -0.030886        0.045536
# 6           -0.068281          -0.114582        -0.099745        0.022261
# 7           -0.073333          -0.116351        -0.104664        0.022391
# 8            0.407884           0.319956         0.364524        0.035907
# 9           -0.080313          -0.188164        -0.137319        0.044245
# 10          -0.088849          -0.124260        -0.117072        0.020742
# 11           0.407884           0.319956         0.364524        0.035907
# 12          -0.058100          -0.111307        -0.091913        0.023995
# 13          -0.073333          -0.116351        -0.104664        0.022391
# 14           0.587228           0.542533         0.570081        0.019673
# 15          -0.096573          -0.210243        -0.152972        0.046410
# 16          -0.148339          -0.177514        -0.175557        0.021469
# 17           0.587228           0.542533         0.570081        0.019673
# 18          -0.053509          -0.114083        -0.088342        0.025551
# 19          -0.073333          -0.116351        -0.104664        0.022391
# 20           0.603600           0.558159         0.585927        0.019877
# 21          -0.098544          -0.208024        -0.152948        0.044698
# 22          -0.224309          -0.234924        -0.243813        0.020539
# 23           0.603600           0.558159         0.585927        0.019877
#
#     rank_test_score
# 0                12
# 1                14
# 2                 7
# 3                13
# 4                18
# 5                 7
# 6                11
# 7                14
# 8                 5
# 9                20
# 10               19
# 11                5
# 12               10
# 13               14
# 14                3
# 15               22
# 16               23
# 17                3
# 18                9
# 19               14
# 20                1
# 21               21
# 22               24
# 23                1
# [CV 1/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END ...C=10, gamma=auto, kernel=linear;, score=0.024 total time=   0.1s
# [CV 2/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.062 total time=   0.2s
# [CV 1/3] END .C=10, gamma=scale, kernel=linear;, score=-0.030 total time=   0.1s
# [CV 1/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.113 total time=   0.2s
# [CV 2/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END ..C=100, gamma=auto, kernel=linear;, score=0.487 total time=   0.2s
# [CV 2/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.104 total time=   0.2s
# [CV 3/3] END .C=100, gamma=scale, kernel=linear;, score=0.487 total time=   0.2s
# [CV 1/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 3/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.2s
# [CV 3/3] END ..C=200, gamma=auto, kernel=linear;, score=0.543 total time=   0.3s
# [CV 3/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.178 total time=   0.2s
# [CV 1/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.122 total time=   0.2s
# [CV 3/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.062 total time=   0.2s
# [CV 3/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.127 total time=   0.2s
# [CV 1/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.106 total time=   0.2s
# [CV 2/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.058 total time=   0.2s
# [CV 2/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.097 total time=   0.2s
# [CV 3/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.210 total time=   0.2s
# [CV 3/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.178 total time=   0.2s
# [CV 1/3] END .C=200, gamma=scale, kernel=linear;, score=0.580 total time=   0.3s
# [CV 2/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.099 total time=   0.2s
# [CV 3/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.208 total time=   0.2s
# [CV 3/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.235 total time=   0.2s
# [CV 3/3] END .C=300, gamma=scale, kernel=linear;, score=0.558 total time=   0.4s
# [CV 1/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 1/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.030 total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.126 total time=   0.2s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.075 total time=   0.2s
# [CV 2/3] END .C=50, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END .C=50, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ....C=50, gamma=scale, kernel=rbf;, score=-0.080 total time=   0.2s
# [CV 3/3] END ....C=50, gamma=scale, kernel=rbf;, score=-0.188 total time=   0.2s
# [CV 3/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.111 total time=   0.2s
# [CV 1/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.097 total time=   0.2s
# [CV 3/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.210 total time=   0.2s
# [CV 3/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.178 total time=   0.2s
# [CV 1/3] END .C=200, gamma=scale, kernel=linear;, score=0.580 total time=   0.3s
# [CV 1/3] END ..C=300, gamma=auto, kernel=linear;, score=0.596 total time=   0.4s
# [CV 2/3] END ..C=300, gamma=auto, kernel=linear;, score=0.604 total time=   0.3s
# [CV 2/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.072 total time=   0.2s
# [CV 2/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 1/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.030 total time=   0.1s
# [CV 1/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.121 total time=   0.1s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.075 total time=   0.2s
# [CV 3/3] END .C=10, gamma=scale, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 3/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.112 total time=   0.2s
# [CV 1/3] END ..C=100, gamma=auto, kernel=linear;, score=0.536 total time=   0.2s
# [CV 2/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.095 total time=   0.1s
# [CV 3/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.138 total time=   0.2s
# [CV 1/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.106 total time=   0.2s
# [CV 2/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 2/3] END ..C=200, gamma=auto, kernel=linear;, score=0.587 total time=   0.3s
# [CV 2/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.097 total time=   0.2s
# [CV 2/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.148 total time=   0.2s
# [CV 3/3] END .C=200, gamma=scale, kernel=linear;, score=0.543 total time=   0.2s
# [CV 1/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 1/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.121 total time=   0.1s
# [CV 2/3] END ..C=10, gamma=scale, kernel=linear;, score=0.024 total time=   0.1s
# [CV 3/3] END .C=10, gamma=scale, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 1/3] END ..C=200, gamma=auto, kernel=linear;, score=0.580 total time=   0.3s
# [CV 2/3] END ..C=200, gamma=auto, kernel=linear;, score=0.587 total time=   0.3s
# [CV 2/3] END .C=200, gamma=scale, kernel=linear;, score=0.587 total time=   0.3s
# [CV 3/3] END .C=200, gamma=scale, kernel=linear;, score=0.543 total time=   0.3s
# [CV 1/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.272 total time=   0.2s
# [CV 2/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.224 total time=   0.2s
# [CV 2/3] END .C=300, gamma=scale, kernel=linear;, score=0.604 total time=   0.4s
# [CV 3/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.116 total time=   0.2s
# [CV 3/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 2/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.062 total time=   0.2s
# [CV 3/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.127 total time=   0.1s
# [CV 1/3] END .....C=50, gamma=auto, kernel=rbf;, score=-0.116 total time=   0.2s
# [CV 2/3] END .....C=50, gamma=auto, kernel=rbf;, score=-0.068 total time=   0.2s
# [CV 3/3] END ...C=50, gamma=auto, kernel=linear;, score=0.320 total time=   0.2s
# [CV 1/3] END ....C=50, gamma=scale, kernel=rbf;, score=-0.143 total time=   0.2s
# [CV 1/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.106 total time=   0.3s
# [CV 2/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.058 total time=   0.2s
# [CV 1/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.201 total time=   0.2s
# [CV 2/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.148 total time=   0.2s
# [CV 1/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.097 total time=   0.2s
# [CV 2/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.054 total time=   0.2s
# [CV 3/3] END ..C=300, gamma=auto, kernel=linear;, score=0.558 total time=   0.4s
# [CV 1/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.152 total time=   0.2s
# [CV 3/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.116 total time=   0.2s
# [CV 3/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.127 total time=   0.2s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.118 total time=   0.2s
# [CV 1/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 3/3] END C=100, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 1/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.148 total time=   0.2s
# [CV 3/3] END ...C=100, gamma=scale, kernel=rbf;, score=-0.201 total time=   0.2s
# [CV 1/3] END .C=100, gamma=scale, kernel=linear;, score=0.536 total time=   0.2s
# [CV 2/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.058 total time=   0.4s
# [CV 1/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.152 total time=   0.2s
# [CV 3/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.210 total time=   0.2s
# [CV 1/3] END .C=200, gamma=scale, kernel=linear;, score=0.580 total time=   0.3s
# [CV 3/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.116 total time=   0.2s
# [CV 1/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.030 total time=   0.2s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.118 total time=   0.2s
# [CV 1/3] END .C=10, gamma=scale, kernel=linear;, score=-0.030 total time=   0.1s
# [CV 3/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.111 total time=   0.2s
# [CV 1/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 1/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.201 total time=   0.2s
# [CV 2/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.148 total time=   0.2s
# [CV 1/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.097 total time=   0.2s
# [CV 2/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.054 total time=   0.2s
# [CV 3/3] END ..C=300, gamma=auto, kernel=linear;, score=0.558 total time=   0.4s
# [CV 1/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.152 total time=   0.2s
# [CV 1/3] END .C=300, gamma=scale, kernel=linear;, score=0.596 total time=   0.3s
# [CV 2/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.072 total time=   0.3s
# [CV 3/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 1/3] END ....C=10, gamma=scale, kernel=rbf;, score=-0.121 total time=   0.2s
# [CV 2/3] END ..C=10, gamma=scale, kernel=linear;, score=0.024 total time=   0.1s
# [CV 3/3] END .C=10, gamma=scale, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 1/3] END ...C=50, gamma=auto, kernel=linear;, score=0.366 total time=   0.2s
# [CV 2/3] END ...C=50, gamma=auto, kernel=linear;, score=0.408 total time=   0.2s
# [CV 3/3] END C=50, gamma=scale, kernel=sigmoid;, score=-0.124 total time=   0.2s
# [CV 1/3] END ..C=50, gamma=scale, kernel=linear;, score=0.366 total time=   0.2s
# [CV 2/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 3/3] END ..C=200, gamma=auto, kernel=linear;, score=0.543 total time=   0.3s
# [CV 1/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.152 total time=   0.2s
# [CV 2/3] END .C=200, gamma=scale, kernel=linear;, score=0.587 total time=   0.2s
# [CV 3/3] END .C=200, gamma=scale, kernel=linear;, score=0.543 total time=   0.3s
# [CV 2/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.099 total time=   0.1s
# [CV 3/3] END ...C=300, gamma=scale, kernel=rbf;, score=-0.208 total time=   0.1s
# [CV 3/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.235 total time=   0.2s
# [CV 1/3] END .C=300, gamma=scale, kernel=linear;, score=0.596 total time=   0.3s
# [CV 1/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.122 total time=   0.2s
# [CV 3/3] END .C=10, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 3/3] END ..C=10, gamma=auto, kernel=linear;, score=-0.087 total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.126 total time=   0.2s
# [CV 2/3] END ..C=10, gamma=scale, kernel=linear;, score=0.024 total time=   0.1s
# [CV 2/3] END ....C=100, gamma=auto, kernel=rbf;, score=-0.064 total time=   0.2s
# [CV 2/3] END ..C=100, gamma=auto, kernel=linear;, score=0.532 total time=   0.2s
# [CV 1/3] END C=100, gamma=scale, kernel=sigmoid;, score=-0.152 total time=   0.2s
# [CV 2/3] END .C=100, gamma=scale, kernel=linear;, score=0.532 total time=   0.2s
# [CV 3/3] END ....C=200, gamma=auto, kernel=rbf;, score=-0.111 total time=   0.2s
# [CV 1/3] END ..C=200, gamma=auto, kernel=linear;, score=0.580 total time=   0.3s
# [CV 1/3] END C=200, gamma=scale, kernel=sigmoid;, score=-0.201 total time=   0.2s
# [CV 2/3] END .C=200, gamma=scale, kernel=linear;, score=0.587 total time=   0.2s
# [CV 2/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.072 total time=   0.3s
# [CV 2/3] END ...C=10, gamma=auto, kernel=linear;, score=0.024 total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.126 total time=   0.2s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.075 total time=   0.2s
# [CV 2/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END C=200, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 3/3] END ..C=200, gamma=auto, kernel=linear;, score=0.543 total time=   0.3s
# [CV 1/3] END ...C=200, gamma=scale, kernel=rbf;, score=-0.152 total time=   0.2s
# [CV 3/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.114 total time=   0.2s
# [CV 1/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 1/3] END ..C=300, gamma=auto, kernel=linear;, score=0.596 total time=   0.4s
# [CV 2/3] END ..C=300, gamma=auto, kernel=linear;, score=0.604 total time=   0.5s
# [CV 1/3] END .....C=10, gamma=auto, kernel=rbf;, score=-0.122 total time=   0.3s
# [CV 2/3] END ...C=10, gamma=auto, kernel=linear;, score=0.024 total time=   0.2s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid;, score=-0.118 total time=   0.2s
# [CV 1/3] END .C=10, gamma=scale, kernel=linear;, score=-0.030 total time=   0.1s
# [CV 3/3] END .....C=50, gamma=auto, kernel=rbf;, score=-0.115 total time=   0.2s
# [CV 1/3] END .C=50, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 1/3] END C=50, gamma=scale, kernel=sigmoid;, score=-0.138 total time=   0.2s
# [CV 2/3] END C=50, gamma=scale, kernel=sigmoid;, score=-0.089 total time=   0.2s
# [CV 2/3] END ..C=50, gamma=scale, kernel=linear;, score=0.408 total time=   0.2s
# [CV 3/3] END ..C=50, gamma=scale, kernel=linear;, score=0.320 total time=   0.2s
# [CV 1/3] END ..C=200, gamma=auto, kernel=linear;, score=0.580 total time=   0.3s
# [CV 2/3] END ..C=200, gamma=auto, kernel=linear;, score=0.587 total time=   0.3s
# [CV 3/3] END ....C=300, gamma=auto, kernel=rbf;, score=-0.114 total time=   0.2s
# [CV 1/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.124 total time=   0.1s
# [CV 2/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.073 total time=   0.1s
# [CV 3/3] END C=300, gamma=auto, kernel=sigmoid;, score=-0.116 total time=   0.1s
# [CV 1/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.272 total time=   0.2s
# [CV 2/3] END C=300, gamma=scale, kernel=sigmoid;, score=-0.224 total time=   0.2s
# [CV 2/3] END .C=300, gamma=scale, kernel=linear;, score=0.604 total time=   0.3s
# [CV 3/3] END .C=300, gamma=scale, kernel=linear;, score=0.558 total time=   0.2s

# %%
#Dynamic input
dy_age = float(input("Age:"))
dy_bmi = float(input("BMI:"))
dy_childrens = float(input("Children:"))
dy_gender = int(input("Sex 0 or 1:"))
dy_smoker = int(input("Smoker 0 or 1:"))

# %%
Prediction=grid.predict([[dy_age,dy_bmi,dy_childrens,dy_gender,dy_smoker]])
print("Prediction={}" .format(Prediction))
