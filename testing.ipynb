# %%
# Importing the Pandas,matplotlib,numpy library
# NumPy library contains multidimensional array data structures
# Pandas library contians read_csv() used to read .csv files
# matplotlib library helps to generate barcharts,scatter plots.
# pd is the alias for pandas
# plt is the alias for matplotlib
# np is the alias for numpy
import matplotlib.pyplot as plt
# import numpy as np
import pandas as pd

# %%
# dataset variable stores values of csv
dataset = pd.read_csv("Salary.csv")

# %%
# printing the csv values stored in memory under variable dataset
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.2   79545
# 17              5.6   81256
# 18              6.2   85781
# 19              6.7   87123
# 20              7.3   88987

# %%
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
# separating Input and Output in dataset
# feature denotes input variable,YearsExperience denotes the column, datatype as float(number comes after decimal point)
# target denotes output variable,Salary denotes the column, datatype as float
feature = dataset[["YearsExperience"]]
target = dataset[["Salary"]]
print(feature)
print(target)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.2
# 17              5.6
# 18              6.2
# 19              6.7
# 20              7.3
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   79545
# 17   81256
# 18   85781
# 19   87123
# 20   88987

# %%
#feature denotes YearsExperience in graph
#target denotes Salary in graph
# '.' denotes the access operator used to re-use the code at any place while coding which avoid re-typing. 
plt.scatter(feature,target, color ="yellow", label ="DataPoints")# scatter method/function in matplotlib library used to show scatter plots
plt.plot(feature,target, color='red', label='Linear Regression Line')
plt.xlabel("YearsExperience", fontsize=20)
plt.ylabel("Salary", fontsize=20)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       1 #feature denotes YearsExperience in graph
#       2 #target denotes Salary in graph
#       3 # '.' denotes the access operator used to re-use the code at any place while coding which avoid re-typing.
#       4 plt.scatter(feature,target, color ="yellow", label ="DataPoints")# scatter method/function in matplotlib library used to show scatter plots
# ----> 5 plt.plot(feature,target, color='red', label='Linear Regression Line')
#       6 plt.xlabel("YearsExperience", fontsize=20)
#       7 plt.ylabel("Salary", fontsize=20)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:487, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     484         kw[prop_name] = val
#     486 if len(xy) == 2:
# --> 487     x = _check_1d(xy[0])
#     488     y = _check_1d(xy[1])
#     489 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1327, in _check_1d(x)
#    1321 with warnings.catch_warnings(record=True) as w:
#    1322     warnings.filterwarnings(
#    1323         "always",
#    1324         category=Warning,
#    1325         message='Support for multi-dimensional indexing')
# -> 1327     ndim = x[:, None].ndim
#    1328     # we have definitely hit a pandas index or series object
#    1329     # cast to a numpy array.
#    1330     if len(w) > 0:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), None)

# %%
# train_test_split() class of sklearn library.
# sklearn.model_selection is python ML package provides functions to split our data into train and test sets. 
# test_size_split is a function which passes the values such as input, output, 
# test_size uses 30% of data for dataset and train_set uses 70% of data for dataset, random_state is a number generator starts from 0)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(feature,target,test_size = 0.33, random_state = 42)

# %%
#Printing the Splitted values X & Y train & test sets.
X_train,Y_train
# Out:
# (    YearsExperience
#  8               8.7
#  13             10.5
#  2               5.9
#  9               9.0
#  16             13.5
#  4               6.8
#  7               8.2
#  10              9.5
#  12             10.3
#  3               6.0
#  6               7.9,
#      Salary
#  8   109431
#  13  121872
#  2    81363
#  9   105582
#  16  175820
#  4    91738
#  7   113812
#  10  116969
#  12  122391
#  3    93940
#  6   101302)

# %%
print(X_test,Y_test)
# Out:
#     YearsExperience
# 0               5.1
# 1               5.3
# 5               7.1
# 15             12.9
# 11              9.6
# 14             12.7     Salary
# 0    66029
# 1    83088
# 5    98273
# 15  161200
# 11  112635
# 14  158600

# %%
from sklearn.linear_model import LinearRegression #sklearn.linear_model is a python ML package along with linearRegression library which determines the straight line
regressor = LinearRegression() # storing the value of LinearRegression class and function in regressor variable
regressor.fit(X_train, Y_train)# calling the fit function from LR function and substituting the parameter's to train & create the model based on linear formula y=mx+c
# Out:
# LinearRegression()

# %%
#following codes used to view weight m and bais/intercept/orgin c values assigned in the formuala y=mx+c
weight = regressor.coef_
print("weight of model:", weight) #coef denotes parameter m that is multiplied by parameter x. A coefficient in linear regression represents changes in a Response Variable 
bais = regressor.intercept_
print("Intercept of model:", bais) #Intercept denotes parameter c in the straight line equation y = mx+c
# Out:
# weight of model: [[10644.39168701]]
# Intercept of model: [19015.00732194]

# %%
Y_pred=regressor.predict(X_test)#predict() function predicts the output of test set and stores the values to the variable Y_pred.

# %%
print(Y_pred)#printing the prediction for X_test input values
# Out:
# [[ 73301.40492567]
#  [ 75430.28326307]
#  [ 94590.18829968]
#  [156327.66008431]
#  [121201.1675172 ]
#  [154198.78174691]]

# %%
#R2_score metrics
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,Y_pred)

# %%
r_score #thus confirming the model has learned good based on the R2 score nearing to 1.
# Out:
# 0.9687073569982435

# %%
#R2 adjusted metrics.

from sklearn.metrics import r2_score
#no_of_observ = 16
#no_of_iv = 6
def adjusted_r2_score(Y_test,Y_pred,no_of_observ,no_of_iv):
    no_of_observ = 16
    no_of_iv = 6
    r_score=r2_score(Y_test,Y_pred)
    adj_r2 = 1 - (1 - r_score) * (no_of_observ-1) / (no_of_observ - no_of_iv - 1)    
    return adj_r2
adjusted_r2_score(Y_test,Y_pred,no_of_observ,no_of_iv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 12
#      10     adj_r2 = 1 - (1 - r_score) * (no_of_observ-1) / (no_of_observ - no_of_iv - 1)
#      11     return adj_r2
# ---> 12 adjusted_r2_score(Y_test,Y_pred,no_of_observ,no_of_iv)
#
# NameError: name 'no_of_observ' is not defined

# %%
print(Y_test,Y_pred)

# %%
X_test,Y_pred

# %%
plt.scatter(X_train,Y_train, color ="yellow", label ="DataPoints")# scatter method/function in matplotlib library used to show scatter plots
plt.plot(X_test,Y_pred, color='red', label='Linear Regression Line')
plt.xlabel("YearsExperience", fontsize=20)
plt.ylabel("Salary", fontsize=20)
plt.legend()
plt.show()

# %%
#Saving model phase
import pickle #pickle is library which converts python objects into binary called as serialization.
filename = "finalized model.sav" #.sav is the statistical file used for statistical analysis purposes such as researching and data mining process.
pickle.dump(regressor, open(filename, "wb")) #wb is write binary,when executing this line finalized model.sav file created inside the directory where .ipynb & .csv file is present

# %%
loaded_model = pickle.load(open("finalized model.sav", "rb")) #rb is read binary
result = loaded_model.predict([[7.9]]) #predicting the salary based on input given in years 15.

# %%
print(result)

# %%
#giving manual input 
prediction_input=float(input("Enter the prediction input value:"))

# %%
Future_Prediction = regressor.predict([[prediction_input]])
print(Future_Prediction) #print("Future_Prediction = {}".format(Future_Prediction))
